# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q -U transformers
# !pip install -q -U peft
# !pip install -q -U accelerate
# !pip install -q -U trl
# !pip install -q -U einops
# !pip install -q -U safetensors
# !pip install -q -U torch
# !pip install -q -U xformers
# !pip install -q -U langchain
# !pip install -q -U ctransformers[cuda]
# !pip install chromadb
# !pip install sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 73.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 32.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 47.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 43.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 7.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.14 requires torch<2.3,>=1.10, but you have torch 2.3.0 which is incompatible.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 85.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.14 requires torch<2.3,>=1.10, but you have torch 2.3.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 30.4 MB/s eta 0:00:00
# Collecting chromadb
#   Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.7.0)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 80.8 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 15.8 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.11.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.3-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 105.4 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 9.7 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 11.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.62.2)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 64.7 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.4)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.6 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.1)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 8.3 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.0 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 41.6 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 94.6 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.4 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=e07a00047b019280bdfabbad9a353469378a85a6533d4cdf35c698b6a1e07f4d
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, python-dotenv, overrides, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.5.0 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.3 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-7.0.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.3 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 overrides-7.7.0 posthog-3.5.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.37.2 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.40.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.7.0

# %%
from google.colab import userdata


from huggingface_hub import login
login(token=userdata.get('HF_Token'))
# Out:
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
from transformers import BitsAndBytesConfig
from langchain import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
llm = HuggingFacePipeline(pipeline=pipeline)

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
model_id = "mistralai/Mistral-7B-Instruct-v0.2"


model_4bit = AutoModelForCausalLM.from_pretrained( model_id, device_map="auto",quantization_config=quantization_config, )
tokenizer = AutoTokenizer.from_pretrained(model_id)

pipeline = pipeline(
        "text-generation",
        model=model_4bit,
        tokenizer=tokenizer,
        use_cache=True,
        device_map="auto",
        max_length=1000,
        do_sample=True,
        top_k=5,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
text = "What is the use of hiletgo gy-521 module in an IoT kit?"

device = 'cuda'
model_inputs = tokenizer(text, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=500, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> What is the use of hiletgo gy-521 module in an IoT kit?
# HILETGO Gy-521 Module: The HIL (Hardware In Loop) Testing System for Automotive and Aerospace Applications. It provides a flexible, cost-effective solution to test automotive control systems under real conditions without risking human life or damaging expensive equipment. With its advanced features such as high accuracy, low latency, and support for multiple protocols, it enables engineers to validate complex system behavior quickly and efficiently.</s>

# %%
text = "What is the use of RC522 RFID Module in an IoT kit? Write the description, applications and technical specifications"

device = 'cuda'
model_inputs = tokenizer(text, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> What is the use of RC522 RFID Module in an IoT kit? Write the description, applications and technical specifications.
#
# Description: The RS-483 module (also known as Modbus) allows for communication between devices using a serial protocol over twisted pair cables or optical fibers. It uses differential signaling to transmit data at high speeds with low noise levels. This makes it ideal for industrial automation systems where reliability and accuracy are critical factors. Some common applications include process control, building management systems, HVAC controls, and machine monitoring. Technical Specifications: - Baud rate range from 19600 bps up to 115200 bps - Data frame length ranging from 7 bytes to 1023 bytes - Parity options available including none, odd parity, even parity, and checksums - Differential encoding used for signal transmission - Compatible with most microcontrollers and computers</s>

# %%
text = "What is the use of Servo Motor SG90 in an IoT kit? Write the description, applications and technical specifications"

device = 'cuda'
model_inputs = tokenizer(text, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> What is the use of Servo Motor SG90 in an IoT kit? Write the description, applications and technical specifications.
#
# SG-91 servos are a popular choice for hobbyists due to their low cost and ease of control with Arduino or other microcontrollers. They have 6V DC motors that can be controlled by sending pulses from your controller's digital pins. The range of motion on these servos is typically around 270 degrees (from fully extended to almost touching), but they can also rotate all the way back up to about 35 degrees past center position if you need them to do so. This makes it easy to create robotic arms or moving platforms using just one motor.</s>

# %%
text = "What is the use of Stepper Motor in an IoT kit? Write the description, applications and technical specifications"

device = 'cuda'
model_inputs = tokenizer(text, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> What is the use of Stepper Motor in an IoT kit? Write the description, applications and technical specifications.
# Stepper Motors are widely used for various purposes such as 3D printing, CNC machines, robotics etc., In this article we will discuss about its usage in Internet Of Things (IoT) kits. A stepper motor converts electrical pulses into mechanical motion by moving a series of electromagnets along fixed tracks or coils to create precise movements with high torque-to-weight ratio. It has become increasingly popular due to its ability to provide accurate positioning control over small distances while consuming minimal power compared to other motors like DC motors. Here's how it works: The motor consists of multiple poles arranged around a central shaft that rotates on bearings at constant speed. Each pole contains one or more permanent magnets which interact with corresponding electromagnetic fields generated by current flowing through wires wrapped around each pole. This interaction creates four distinct magnetic field regions within the motor - north, south, east, west. By applying these magnetic fields sequentially using microcontrollers connected via pulse width modulation (PWM), the motor can be made to move precisely in any direction desired. Applications of Stepper Motors in IoT Kits include:
# 1. Robotics: With their precision and accuracy, stepper motors make them ideal for robotic systems where exact movement is required. They are commonly used in industrial automation, medical devices, drones, and even home appliances like printers and scanners.
# 2. Automated Manufacturing Processes: These motors have found widespread adoption in automated manufacturing processes because they offer consistent performance under heavy loads without requiring frequent maintenance. Their low noise levels also contribute significantly towards improving overall productivity.
# 3. Precision Positioning Systems: Due to their capability to maintain high resolution positions, stepper motors find application in many industries including surveying equipment, optical instruments, scientific research tools, and space exploration technology.
# 4. Additive Printing Technology: As additive printing becomes more mainstream, stepper motors play a crucial role in creating intricate designs layer by layer. Their fine adjustments allow for highly detailed prints with excellent surface finish. Technical Specifications: There are several factors you should consider when choosing a stepper motor suitable for your project. Some key parameters include:
# a) Resolution: Determines the number of steps per inch/millimeter that the motor takes during rotation. Higher resolutions result in smoother operation but require higher voltage inputs. b) Torque Capacity: Refers to the maximum force the motor can generate before experiencing damage. c) Speed Range: Indicates the range of speeds at which the motor operates efficiently. d) Power Consumption: Depends heavily on the size and type of motor being considered. e) Acceleration Rate: Measures how quickly the motor accelerates from rest to full speed. f) Efficiency Rating: Represents the amount of energy converted from input power to output work. g) Environmental Factors: Such as temperature, humidity, vibration resistance etc., must be taken into account depending upon the intended environment of the device.</s>

# %%
text = "What is the use of Water Level Detection Sensor Module in an IoT kit? Write the description, applications and technical specifications"

device = 'cuda'
model_inputs = tokenizer(text, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> What is the use of Water Level Detection Sensor Module in an IoT kit? Write the description, applications and technical specifications.
# Water level detection sensor module helps to measure water levels accurately by using ultrasonic technology or capacitive sensing method. This type of sensors are widely used for various purposes such as monitoring liquid levels in tanks, reservoirs, wells etc. The main advantage of this sensor over other traditional methods like dipsticks is that it provides a non-invasive way to check the fluid levels without physically touching them which can cause contamination.
# Applications:
# 1. Agriculture - Farmers can monitor soil moisture levels with these sensors to optimize irrigation systems and reduce wastage.
# 2. Industrial Processes - These sensors help industries to maintain optimal operating conditions in their processes such as chemical reactions, cooling towers, boilers etc.
# 3. Home Automation - Smart homes can be equipped with these sensors to control lighting, heating/cooling system based on occupancy patterns and weather forecasts.
# 4. Environmental Monitoring - Scientists can use these sensors to study groundwater quality, river flow rates, ocean tides etc.
# Technical Specifications:
# The most common types of water level detection sensors include Ultrasonic and Capacitance probes. Here's what you need to know about each one:
# Ultrasound Probe: It uses high frequency sound waves (usually above 50 kHz) to bounce off objects underwater and calculate distance between those two points. Its accuracy depends on factors like temperature, pressure changes and interference from nearby devices. Some popular brands of ultrasonic probe manufacturers include MaxSonar, Vishay Precision Group, HBM.
# Capacitance Probes: They work by measuring electrical charge stored within dielectric materials when they come into contact with liquids. Their sensitivity varies depending on the material properties but generally higher than ultrasonic probes. Popular brands of capacitance probe manufacturers include Omega Engineering, ABB Measurement & Control, Endress+Hauser.</s>

# %% [markdown]
# # ZERO SHOT PROMPTING

# %%
text_01 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_01, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]</s>
# 1)Description:
# The HC-05 / GC-05 / Gy-521 is a popular Bluetooth v4.0 Low Energy Module, also known as BLE or BT LE. This module comes from the Chinese manufacturer "Hitech Info Tech Co., Ltd." It's based on the CC2650 chipset by Texas Instruments (TI). The main function of this module is to act as both a transmitter and receiver for sending and receiving data over short distances using Bluetooth technology. With its compact size, it can be easily integrated into various projects such as wearable devices, home automation systems, health monitoring gadgets, etc. Its versatility makes it suitable not only for DIY enthusiasts but also professional developers looking for cost-effective solutions.
#
# Key features include built-in antenna, AT command support, adjustable baud rate up to 9600bps, configurable UART pins, and compatibility with Android, iOS, Windows, Linux platforms among others through their respective SDKs. Additionally, users may program custom applications via Arduino IDE due to its open source nature.
#
# 2)Applications:
# a) Home Automation Systems - Control lights, appliances, temperature settings remotely within your house.
# b) Health Monitoring Devices – Track vital signs like heartbeat, blood pressure, oxygen saturation levels wirelessly.
# c) Wearables & Fitness Gadgets– Design smartwatches, fitness bands that connect seamlessly with mobile apps.
# d) Industrial Process Controllers – Implement real-time remote control and monitor industrial processes.
# e) Proximity Sensors – Create proximity sensors triggering alerts when objects come close or leave certain areas.
# f) Wireless Data Loggers – Collect environmental sensor readings at regular intervals without wires.
# g) Intercom System – Develop intercommunication systems between different rooms or buildings.
# h) Remote Keyless Entry Systems – Secure access points while maintaining convenience.
# i) Educational Projects – Enrich learning experiences related to electronics, programming, robotics, etc.
# j) Art Installations – Integrate interactive elements controlled via Bluetooth connection.
# k) Asymmetric Warfare Training Simulators – Enable wireless communication between team members during training exercises.
# l) Smart Agricultural Solutions – Remotely manage irrigation schedules, soil moisture level checks, livestock tracking, etc.
# m) Security Alarm Systems – Set off alarms upon detection of intruders or other unwanted events.
# n) Drone Navigating Components – Assist drones in navigating complex environments autonomously.
# o) Indoor Positioning Systems – Determine precise locations indoors where GPS signals might otherwise fail.
# p) Beacons for Location Based Services(LBS)- Provide location information to nearby devices enabling services tailored according to user preferences.
# q) Augmented Reality Experiences – Trigger AR content delivery based on geolocation or object recognition.
# r) Telemetry Transmission Units – Send critical machine performance metrics back to central servers for analysis.
#
# 3)Technical Specifications:
# Name : HC-05 / GC-05 / Gy-521
# Chipset : TI CC2650F512RFA2
# Operating Voltage Range : DC 3V~8V
# Bluetooth Version : V4.0 + EDR, V4.1+BLE
# Transmit Power Level : <+7 dBM @ 1 m, Class II device
# Receiver sensitivity (-85dbM ~ -95 dbM@1% packet error rate)
# Data Transfer Rate : Up to 3 Mbit/sec
# Memory Capacity : Flash Memory: Maximum 1MB; SRAM: Minimum 16 Kbytes
# Communications Protocol Support : AT Command set, HCI commands, LMPP profile, OTA firmware update
# Uart Pins Configuration Options : RXD, TXD, CTS, RTS
# Dimensions : Approx. 35mm x 20 mm x 6mm
# Weight : Around 10 grams including PCBA and Antenna
# Antennas Type : Built-in patch type dipole antennas
# LED indicators : Status LED (Power ON), Connection status indicator light (Blue/Red)
# Interfaces : USB interface for charging and flashing new software versions, JTAG debugging connector if required.
# Mounting Holes : Four standard mounting holes provided along edges for easy integration onto boards or panels.</s>

# %%
messages = [
    {"role": "user", "content": "You are an expert in IoT and hardware with extensive experience."},
    # {"role": "assistant", "content": "Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavour to whatever I'm cooking up in the kitchen!"},
    {"role": "user", "content": "Do you have mayonnaise recipes?"},
]

# %%
text_02 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_02, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]</s>
# 1) **Description:**
# The RC522 is a microcontroller-based RFID reader module that supports Mifare Classic cards, including MIFARE PICC (Passive Infrared Proximity Card), MIFAре SAM AV1 (Single Antenna Model A very high frequency Integrated Circuit), and MIFAre NFC Forum Type B tag standards. It operates at a frequency of 13.56MHz and uses the HF (High Frequency) technology for data communication between the reader and tags or smartcards. The module comes equipped with four pins - VCC, GND, SDN (Serial Data Network), and MOSI/SCK (Master Output Slave Input Serial Clock). These pins allow users to interface it easily with various types of controllers such as Arduino boards, Raspberry Pi, etc., enabling them to create custom applications using this versatile device.
#
# 2) **Applications:**
# RC522 modules find their use cases primarily within the Internet of Things (IoT) ecosystem due to their ability to read and write information from contactless Smart Cards like MiFare classic cards. Some common application areas include access control systems where these readers can be used to grant entry into secure facilities based on predefined permissions stored on user's ID card; ticketing solutions allowing automatic fare collection through buses, trains, metro stations, parking lots, amusement parks, museums, libraries, events, stadiums, airports, hospitals, schools, universities, offices, residential complexes, hotels, retail stores, warehouses, logistics centers, factories, laboratories, research institutions, military bases, government buildings, embassies, consulates, border crossings, customs checkpoints, toll plazas, fuel dispensers, vending machines, ATMs, kiosks, locker rooms, gyms, swimming pools, sports arenas, theme parks, waterparks, ski resorts, cruise ships, cargo containers, shipping yards, oil rigs, wind farms, solar power plants, telecommunication towers, satellite ground stations, weather monitoring networks, wildlife tracking projects, agriculture automation, livestock management, animal shelters, pet identification chips, asset tracking, inventory management, supply chain optimization, warehouse security, anti-theft protection, vehicle immobilization, fleet management, container freight station surveillance, industrial process controls, energy harvesting, environmental sensing, geolocation services, emergency response teams, disaster recovery operations, search & rescue missions, space exploration programs, autonomous vehicles, drones, robotics, augmented reality games, virtual assistants, home appliances, wearable devices, fitness trackers, health monitors, eHealth records, electronic passport gates, biometric authentication, digital signatures, mobile payments, loyalty rewards, coupons, event tickets, membership cards, library books borrowing system, public transportation fares, automated door locks, garage doors openers, key fobs, remote car starters, wireless alarm systems, baby monitor alerts, elderly care alert systems, pet feeders, aquarium filters, irrigation timers, garden sprinklers, greenhouse climate controller, farm equipment autonomy, construction site safety checks, mining operation efficiency analysis, marine vessel navigation, aviation industry maintenance schedules, wildfire detection, earthquake early warning systems, volcanic eruption prediction models, underwater exploratory rovers, deep sea submersibles, lunar base infrastructure development, Martian habitat establishment, interplanetary colonization efforts, asteroid resource extraction, and more.
#
# 3) **Technical Specifications:**
# - Operating Frequency: 13.56MHz ISM band
# - Communication Protocol: ISO 14443A /B, Felica, EM4100S II, TagItSmartStream, iCLASS EV1, DESFire, MIFARE Standard, MIFARE Plus, MIFARE Ultral Light IC, MIFARE Deep Memory, MIFARE MiniLight, MIFARE One, MIFARE Select, MIFARE Open System, MIFARE Purple, MIFARE Gold, MIFARE Silver, MIFARE Green, MIFARE Blue, MIFARE Red, MIFARE Black, MIFARE Orange, MIFARE Yellow, MIFARE Pink, MIFARE Twin, MIFARE Trios, MIFARE JEDEC EAS, MIFARE Form D, MIFARE Des Fire SEOS, MIFARE DESFire Evolution, MIFARE Secure Element, MIFARE Advanced Encryption Standard, MIFARE Digital Signature, MIFARE Key Management Service, MIFARE File Access Control, MIFARE Message Authentication Code, MIFARE Block Write Protect, MIFARE Anti Collision, MIFARE Virtual Zone Security, MIFARE Physical Access Control, MIFARE Logical Access Control, MIFARE Contactless Identification, MIFARE Emulation, MIFARE Static Data Locking, MIFARE Read Only Reference Target, MIFARE Transition Object, MIFARE Interactive Application, MIFARE JavaCard, MIFARE Download On Demand, MIFARE Remote Downlink, MIFARE Over The Air Configuration, MIFARE Reusable Kernel Architecture, MIFARE Enhanced Privacy, MIFARE Extended Access Rights, MIFARE High Capacity, MIFARE SuperCapacitor, MIFARE Power Manager, MIFARE Fast Track, MIFARE Expressive, MIFARE Mobile, MIFARE NDEF Format, MIFARE Gen 2, MIFARE Legacy, MIFARE Ultra Light C, MIFARE Ultra Light S, MIFARE CLASSIC, MIFARE PLUS, MIFARE PROXIMITY_I, MIFARE PRIVATE LOOP, MIFARE FORMAT 'A', MIFARE FORMAT 'B'.
# - Maximum Reading Range: Approx. 8 cm when no obstacles present
# - Dimensions: ~7 x 4cm²
# - Weight: <1gm
# - Supply Voltage: DC 3V~5.5V
# - Current Consumption: Standby mode – less than 9 mAh per year; Active Mode – up to 1Watt max
# - Temperature range: -20°C to +70°C (-4℉to+158ÅF)
# - Compatible Controllers: Microcontrollers supporting SPI protocol and UART serial communications. Common examples include but not limited to Arduinos, ESP32 series, STMicroelectronics MCUs, Texas Instruments CCxxxxx series, Cypress Semiconductors PSoC® CPUs, Renesas Electronic Devices, Infineon Technologies XMC Series, Freescale Semiconductor ARM Cortex™-R Processors, Atmel Corporation AVR microprocessors, Silabs Wireless Gecko SoCs, Nordic nRF52 Series, Dialog Semiconductor DA1458x family members, Qualcomm QCA6XXX series, Broadcom BCM2073x series, Marvell Avastar WiFi chipsets, Intel Quark processor families, Lattice semiconductor Mach-Zehnder modulator arrays, Analog Device ADSP-BF533 series, Altera Cyclone III FPGAs, Xilinx Spartan-III FPGA, Actel IGLOOII flash FPGAs, Field Programmable Gate Array(FPGA)/Complex programmable logic devises(CPLD) based designs, etc.
# - Mounting Options: Can be mounted directly onto PCB board via soldering technique or connected externally by wires depending upon design requirements.</s>

# %%
text_03 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_03, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]</s>
# 1) **Description:**
# The SG90 is a standard-sized servo motor commonly used in hobbyist projects, robotics applications, model airplanes or cars, and other small mechanical systems where precise position control is required. It's called "standard" because it conforms to the general size (approximately 57mm long x 46 mm wide), weight, and electrical characteristics defined by TowerPro MG90S which makes it compatible with most RC receivers and controllers designed for this type of actuator. The SG90 features three wires – power supply (+Vcc), ground (-GND), and signal input (IN). Its compact design includes a built-in potentiometer that allows adjusting its center position during operation without requiring external components like trims pots. This feature simplifies setup processes significantly when integrating multiple motors into complex mechanisms.
#
# 2) **Applications:**
# Some common uses cases for SG90 servos include controlling flaps on remote controlled aircraft models, moving parts within robotic arms, creating pan & tilt camera mounts, operating doors or hatches, managing antennas or solar panels orientation, etc. Due to their affordability, reliability, ease of use, and versatility, these miniature servos can be found across various DIY electronics projects involving automation, home security systems, educational labs, art installments, and more. They also serve well as test subjects while experimenting new ideas related to motion sensing, feedback loops, PID algorithms, or even machine learning techniques.
#
# 3) **Technical Specifications:**
# Here are some key technical details about typical SG90 servos:
#  - Operational Voltage Range: 4.8 V DC ~ 6.2 V DC
#  - Stall Torque: Approx. 1 kg cm / 10 Nm
#  - Max Angle Rotation: ±90 degrees from neutral position
#  - Speed at no load: Up to 0.1 seconds per degree
#  - Power Consumption @ full speed: Around 1 Watt
#  - Weight: Roughly 30 grams including gear train and connector cables
#  Note that actual values may vary slightly depending upon manufacturing tolerances between different batches or individual units. Always consult datasheets provided by your supplier if you need exact numbers for designing custom circuits or optimizing performance parameters.</s>

# %%
text_04 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_04, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]</s>
# **Description:**
# A stepper motor is an electromechanical actuator that converts electrical pulses into mechanical rotational motion, moving a specified number of steps each time it receives a pulse sequence. It consists of a stator (stationary part), which has multiple coils arranged around its periphery, and a rotor made up of several salient poles or permanent magnets. The interaction between these stationary and rotating magnetic fields causes the rotation of the shaft in small angular increments called "steps." This precise control over movement makes stepper motors ideal for applications requiring accurate positioning such as CNC machines, printers, robotics, and automation systems.
#
# Stepper Motors come in various sizes, shapes, and configurations like unipolar and bipolar based on their winding arrangements. Unipolar motors use one voltage source per phase while bipolar ones require separate sources to apply both positive and negative voltages. Additionally, there's also hybrid stepping motors combining features from both types.
#
# (Image Source: https://www.reichelttechnik.de/en-us/steppermotors_c405786.html?gclid=CjwKCAiAmJqOBhBdEiwAhvZzLRlQbW9XNnYkMfUxoGmVtBoPpDHrOeFaS8IQUIPzMTJzvRoCL-ZjhoBOsQAvD_BwE&utm_source=google&utm_medium=organic&utm_campaign=shopping_english&utm_content=productpage&prodId=113333)
#
# **Applications:**
# 1. **Printers**: In desktop inkjet and laser jet printers, stepper motors move print heads along X & Y axes accurately placing dots onto paper during printing process.
# 2. **Robotic Arm Control**: Steppers provide smooth movements required by robotic arms used in manufacturing industries where precision matters most. They help manipulate objects through controlled angles ensuring consistent results every single time.
# 3. **Automated Machines**: From industrial machinery like conveyer belts assembly lines to home appliances like washing machine drums - all rely upon stepper motors for reliable operation and fine tuned adjustment capabilities.
# 4. **Engravers and Milling Machines**: These tools employ stepper motors to create intricate designs using tiny incremental moves across surfaces. Their high torque capacity allows them to handle heavy loads efficiently.
# 5. **Camera Focus Systems**: Autofocus mechanisms found within DSLR cameras utilize steppers enabling quick focusing accuracy even when shooting macro images or videos.
#
# **Technical Specifications:**
# Some common technical parameters defining performance characteristics include:
# * Number Of Phases: Determining whether it’s unipolar, bi polar or hybride type.
# * Voltage Rating: Maximum operating voltage level; e.g., 12 V DC, 24 V AC etc.
# * Current Draw: Amount of current flowing through windings under load conditions.
# * Torque: Force generated at different speeds indicating how much weight can be moved against friction forces present.
# * Resolution: Minimal angle change achieved after receiving one full set of input signals i.e., microstepping resolution.
# * Speed Range: Operable RPM range providing information about maximum achievable speed levels.
# * Acceleration And Decelaration Rate: How fast the motor accelerates towards top speed and decelerates back down respectively.
# * Mechanical Shaft Size: Diameter and length specifying compatibility issues related to mounting requirements.
# * Environmental Conditions: Temperature limits, humidity tolerance, vibration resistance etc. affecting longevity and reliability aspects.</s>

# %%
text_05 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_05, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]</s>
# **Description:**
#
# The Water Level Detection SensorModule is a compact, versatile device designed for monitoring water levels in various applications such as aquaculture systems, irrigation projects, rainwater harvesting systems, or industrial processes where keeping track of fluid level is essential. This sensor module uses ultrasonic technology to measure distances between itself and the target liquid surface by sending sound waves that bounce back when they hit the water's surface. The time it takes for these echoes to return provides valuable information about the current water level height.
#
# Key features include:
# - Ultra-low power consumption (ideal for battery operated devices).
# - High accuracy and resolution.
# - Widely compatible communication interfaces like I²C, UART, RS485 etc., enabling seamless integration into different control platforms and microcontrollers.
# - Robust design suitable for harsh environments - IP67 rated enclosure protects against dust ingress and immersion up to one meter depth underwater.
#
# **Applications:**
#
# Some common use cases for thisWaterLevelDetectionSensorModuleinclude:
# 1. Aquaponics Systems – Monitor fish tank waterlevelsto maintain optimal conditionsfor bothfishandplants.
# 2. Flood Warning System– Detect rising floodwatersin realtimeto prevent damagefrom flooding.
# 3. Industrial Process Control– Keeptrackofliquidsuppliesorcoolantlevelsinsuch industriesaschemicalprocessing,foodproduction,pharmaceuticals,etc.
# 4. Agriculture &Irrigation–Monitorreservoirorcanalsupplylevelsinreal-timeto optimizeirrigation schedulingandreducewasterunoff.
# 5. HVAC&RSystems–Controlheatingventilationairconditioningsystemswithaccurateinformationaboutthecurrentstateofthewatertankorcondensatetanks.
#
# **Technical Specifications:**
#
# GeneralSpecification:
# - Operational Temperature Range:-10°C ~ +50°C(14℉~122℉)
# - Measurement Principle :Ultrasound
# - Output Signal Type:Analog voltage output / Digital serial interface
# - Communication Interface Options: I²C, UART,RS485
# - Power Supply Voltagerange: DC9V-DC36V
# - Accuracy @ 2m measurement range:±(0.5%+2mm)
# - Resolution@ 2mmeasurementrange: ±1 mm
# - Dimensions: Approx. L xW xH (cm): 6.5×3.5 ×1.5
#
# For more detailed technical datasheet refer manufacturer documentation.</s>

# %% [markdown]
# # ONE SHOT PROMPTING

# %%
text_11 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here is an example for reference,

ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_11, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here is an example for reference,
#
# ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects</s>
#
# Now let's describe HILTECH GO Gy-521 WiFi Enabled Bluetooth & LoRaWAN Sensor Node:
#
# Description:
# Hiltec Go Gy-521 is a versatile sensor node that combines WiFi connectivity along with Bluetooth Low Energy (BLE) and Long Range Wide Area Network (LoRaWAN). The compact device can collect data from multiple sensors such as temperature, humidity, light level, sound intensity, vibration, proximity, magnetic field strength, barometric pressure, and more. With built-in security features, it offers secure communication between devices and cloud platforms.
#
# Applications:
# This multi-functional sensor node has numerous potential uses across industries and personal projects, some examples include:
# Smart Agriculture: Monitor soil moisture levels, air quality, and weather conditions remotely.
# Industrial Automation: Control processes by monitoring environmental factors and machine performance parameters.
# Home Security Systems: Detect intrusions using PIR motion detectors and send alerts via email or text message.
# Healthcare Devices: Track vital signs wirelessly and transmit real-time health information to healthcare providers.
# Environmental Research Projects: Collect climate change data over large areas through low power networks.
# Educational Purposes: Teach students about wireless communications and Internet of Things concepts.
#
# Technical Specificatons:
# Communication Protocols: Supported protocols - WiFI(802.11bgn), Bluetooth v4.2 LE, LoRaWAN Class A / C
# Power Supply: Operates at 3.7 VDC input; supports external battery packs or USB connection
# Sensors: Supports wide range of available sensors depending upon user requirements
# Memory Capacity: Internal flash memory stores collected data locally before transmission
# Connectivity Ranges: Up to several kilometers for long-range transmissions using LoRaWAN network
# Security Measures: Encrypted communication channels ensure privacy and protection of sensitive data
# Size: Small form factor allows ease of deployment even in remote locations
# Programming Languages: Compatibility with popular programming languages like Python, MicroPython, and others enables customization according to project needs.</s>

# %%
text_12 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here is an example for reference,

ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_12, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here is an example for reference,
#
# ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects</s>
#
# Now let's discuss about the RC522 RFID Module:
#
# Description:
# RC522 Mifare SAM AV1 / NTAG2xx series RFID reader module is based on MIFARE technology from Philips Semiconductors. The compact design makes it suitable for numerous identification and access control applications such as electronic locks, turnstiles, automatic gates, etc. With support for multiple tag types, this versatile module can read data stored on standard MiFare Classic cards and newer tags using different encryption methods.
#
# Applications:
# Some common uses cases include but not limited to:
# Access Control Systems: Secure entry points at homes, offices, parking lots, schools, hospitals, etc., by granting authorized users permission through their unique ID card or key fob.
# Asset Tracking & Management: Monitor inventory levels, manage assets efficiently within warehouses, libraries, museums, laboratories, and other facilities where tracking items plays a crucial role.
# Smart Home Automation: Integrate smart home devices that respond automatically when certain conditions are met – e.g., unlocking doors upon detecting valid user credentials or turning lights off after leaving the room.
# Retail Industry: Implement contactless payment solutions allowing customers to make transactions quickly without requiring physical cash exchange during checkout processes.
# Gaming Projects: Create interactive games involving virtual treasure hunts, puzzles, or challenges triggered via proximity sensors attached to these modules.
#
# Technical Specificaitons:
# Communication Protocol: ISO 14443 Type A and B
# Supported Tags: Standard MiFARE classic cards, DESFire EV1 keys, Ultralight Cards, TagIt SmartMX, ICODE SLx, FEELeXx, HITAG II, and more depending on firmware version used.
# Power Supply: Operates between +3.3 VDC - 5.5 VDC input power range; recommended operating voltage is around 4.8 VDC.
# Interface: Serial Peripheral Interface Bus (SPI), which allows communication over short distances while consuming minimal resources compared to USB connections.
# Size: Approximately 29mm x 25mm x 6mm
# Weight: Around 1 gram
# Security Level: Supports several security features like Triple DES Encryption, Access Rights management, Anti Collision mechanism, and Authentication algorithms ensuring secure handling of sensitive information.</s>

# %%
text_13 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here is an example for reference,

ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_13, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here is an example for reference,
#
# ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects</s>
#
# Now let's discuss about Servo Motor SG90:
#
# Description:
# Servo Motor SG90 is a small servomotor that offers accurate angular displacement under external electrical control. The compact design makes it suitable for numerous robotic and automation tasks where precision movement is required. These types of motors consist of three main parts - the actuator itself, gear train, and feedback mechanism which ensures consistent performance by providing continuous rotation within specified limits.
#
# Applications:
# SG90 Servos find their place in several areas such as model aircraft building, RC cars & boats, CNC milling machines, educational kits, and other DIY electronics projects requiring fine adjustments and controlled rotational movements. They can also serve well in industrial processes involving repetitive actions needing high accuracy levels.
#
# Technical Specificatons:
# Motive Force: Approximately 8 oz.-inch / 1 kg·cm at no load
# Speed Range: Continuous operation from approximately 0.05 seconds to 0.1 second depending upon torque requirements
# Torque Capability: Maximum stall torque – around 1.2kg cm
# Power Requirements: Operates efficiently between 4.8 VDC and 6.0 VDC; however, higher voltages may increase speed but reduce life expectancy
# Size: Typically measures ~6 x 3 centimeters long making them ideal for space constrained designs
# Weight: Weighs less than half an ounce allowing ease during transportation and handling
# Resolution: Can achieve resolution down to ±0.1 degrees when used correctly with appropriate controller settings
# Connectivity: Generally comes equipped with standard JST XH type connectors facilitating simple connection procedures.</s>

# %%
text_14 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here is an example for reference,

ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_14, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here is an example for reference,
#
# ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects</s>
# Note that these technical specs may vary depending upon different manufacturers' versions of this driver module. Always refer to your particular manufacturer’s datasheet when designing circuits around their product.</s>

# %%
text_15 = """<s>[INST]ou are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here is an example for reference,

ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_15, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]ou are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here is an example for reference,
#
# ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects</s>
#
# ---
# Water Level Detection Sensor Module:
# Description:
# The Water Level Detection Sensor Module uses ultrasonic technology to measure water levels accurately within tanks or containers. The sensor emits sound waves that travel through air towards the liquid surface; when these waves return after hitting the water's surface, they create echo signals which can then be measured by the receiver part inside this module. These measurements help determine the distance between the sensor probe tip and the water level.
# Applications:
# This versatile sensor has numerous potential applications such as:
# Monitoring reservoirs, pools, aquariums, rainwater harvesting systems, sewage treatment plants, hydroponic gardens, irrigation systems, etc., ensuring efficient management of liquids at all times.
# Real-time monitoring of industrial processes involving fluid storage and transfer, enabling predictive maintenance and reducing downtime due to overflow conditions.
# Smart agriculture solutions where accurate measurement of soil moisture content plays a crucial role in optimizing crop yield while conserving resources.
# Flood detection systems used in urban planning and disaster risk reduction initiatives.
# Technical Specificatons:
# Sensing Principle: Ultrasound Technology
# Measuring Range: Up to approximately 8 meters depending upon environmental factors
# Accuracy: ±(X%) typically, where X depends on application requirements
# Power Supply: Operates using +5 VDC power supply
# Communication Protocol: Supported communication protocols include I²C, SPI, RS-485 Modbus RTU, NPN Transistor Output, TTL Serial output, among others based on customer preference
# Environmental Conditions: Temperature range from -10°C to +60°C (-14°F to +140°F), IP65 rated enclosure protection against dust ingress and splash water resistance.
# Size & Weight: Typically compact dimensions suitable for space constraints in embedded designs. Lightweight design allows ease during transportation and handling.</s>

# %% [markdown]
# # TWO SHOT PROMPTING

# %%
text_21 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries</s>
"""

device = 'cuda'
model_inputs = tokenizer(text_21, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries</s>
#
# Now coming back to your question regarding HILTEGO Gy-521 module, here's some information about this particular IoT Kit Component:
#
# Description:
# HILETGO Gy-521 WiFi ESP32S2 Development Board is part of the Internet of Things ecosystem that combines the functionality of a development board along with built-in wireless connectivity using Espressif Systems’ ESP32S2 chipset. The board offers accessibility through multiple communication protocols such as WiFI, Bluetooth, OTA updates, and MicroSD card support making it suitable for building smart devices, data loggers, remote controls, and other IoT projects.
#
# Applications:
# Some common uses cases include but not limited to:
# Smart Home Automation Projects - Control lights, appliances remotely via mobile apps or web browsers.
# Environmental Monitoring – Collect temperature, humidity readings from different locations wirelessly.
# Healthcare Devices – Develop wearable health monitoring gadgets capable of sending real-time patient vitals over the internet.
# Industrial Process Controlling System– Implement industrial process controllability solutions where equipment status needs constant supervision.
# Educational Purposes – A perfect learning toolkit for individuals interested in gaining hands-on knowledge related to IoT technologies.
# Real Time Data Logging & Transmission – Create customized logging platforms transmitting collected data directly online.
# Interactive Installations – Design engaging art pieces featuring responsive elements controlled through WiFi connections.
#
# Technical Specificatons:
# Processor: Espressif ES32S2 SoC @ 240Mhz dual-core CPU
# WiFi Connectivity: Dual band WiFi 4 / WiFi Direct / SoftAP mode / Station+SoftAP modes
# Bluetooth Capabilities: Classic BT + EBT(ESP_now, BLE Scanner, GATT server&client)
# Memory: Flash memory: 520Kb SS RAM: 520kb SD Card Supported (up to 1GB VFS FAT file system)
# Power Supply: USB type C input power supply; Operating voltage: 5VDC
# Expansion Connections: GPIO pads, Analog inputs, SPI, I²C, SDA, SCL, JTAG, SWD, Tx/Rx LED indicator, Power key button etc.,
# Communication Protocols supported : HTTP, SMTP, SNMP, NTP, FTP, Telnet, SSL/TLS, MQTT, CoAP, LwIP, Static IP address assignment, WebSocket, RESTful API, JSON, XML, TCP/UDP sockets, Modbus RTU, MODBUS TCP, CAN bus, I2C, One Wire, DS18B20, Real time clock, RTC Alarm Manager, File handling functions, Serial Peripheral Interfaces (SPI).</s>

# %%
text_22 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_22, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries</s>
#
# Now let's discuss your provided component - The RC522 RFID Module:
#
# Description:
# RC522 RFID Module is a popular contactless smart card reader that supports reading and writing data from MIFARE Classic cards and NFC tags using HF technology. Based on Philips Semiconductors SQ500x series chips, this module offers simple communication via SPI protocol making it suitable for implementing access control, ticketing, identification, tracking, and other similar applications.
#
# Applications:
# Some common uses cases include but not limited to:
# Access Control Systems: Secure entry points such as gates, turnstiles, elevators, etc., ensuring only authorized individuals gain entrance.
# Tickets & Passes: Implement electronic tickets at events, public transport services, parking lots, amusement parks, museums, sports stadiums, among others.
# Identification Cards: Create secure ID badges for employees, students, members, visitors, patients, customers, etc.
# Tracking Assets: Monitor inventory levels, equipment usage patterns, vehicle fleets, livestock management, library books, and assets within warehouses or facilities.
# Data Logging: Store information about temperature readings, humidity conditions, vibration measurements, energy consumption, water quality parameters, geolocation coordinates, time stamps, and any relevant metadata related to monitored objects.
# Interactive Installations: Develop creative art pieces where people interact through touchless interactions involving scanning QR codes or tapping NFC enabled devices onto the system.
# Smart Home Automation Projects: Integrate these readers into security systems, lighting controls, appliance switches, door locks, garage openers, thermostats, entertainment centers, and many other aspects of modern homes.
# Educational Purposes: Use them in classrooms, labs, workshops, hackathons, maker spaces, science fairs, and STEM programs to teach concepts around wireless technologies, coding, engineering principles, cybersecurity, privacy concerns, and ethical considerations surrounding digital identity verification methods.
#
# Technical Specificatiosn:
# Communication Protocol: Serial Peripheral Interface Bus (SPI)
# Supply Voltages: VCC = +3.3VDC; GND (-GND); Antenna (+ANTENNA)
# RF Frequency Range: ISM band – 13.56 MHz
# Memory Capacity Supported: Up to 1Kb EEProm
# Read Distance: Approximately 1 cm to several centimeters depending upon tag type and antenna configuration
# Write Distance: Similar to Read distance
# Power Consumption: Typically less than 9 mW during operation
# Size: Small form factor measuring approximately 2 inches long, 1 inch high, and half an inch thick
# Interface Connections: Four pads labeled 'SCK', 'MOSI','MISO,' and 'CS'. Additionally, there may also be power supply connections ('+Vcc', '-Gnd') along with ground pad for ANTENNA connection. Some versions might come preassembled while some require soldering individual parts together before mounting them on PCB boards.</s>

# %%
text_23 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_23, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries</s>
#
# Now let's move onto our next topic - The servo motor SG90!
#
# Description:
# SG90 is one of the most popular types of continuous rotation servos available today due to its affordability, reliability, and broad applicability. A standard RC model airplane servomotor, this type features a rotational angle movement ranging from approximately 0° to +90° degrees. These small yet powerful devices consist primarily of three main parts – a gear train that converts electrical energy into mechanical force, a potentiometer to sense feedback about current shaft position, and a torque arm assembly connecting the motor body to the load being controlled.
#
# Applications:
# Servo motors such as the SG90 find application in diverse areas where precision angular displacement needs to be achieved consistently under varying loads. Some common uses include:
# Model Aircraft & Helicopters: For precisely maneuvering wings, tail surfaces, landing gears, etc., ensuring stable flight characteristics.
# RC Cars & Boats: To steer wheels, change directional flow of water jets, adjust suspension settings, among other functions.
# Mechanized Models: In intricate models requiring fine positional changes during operation, e.g., animatronics, puppetry, kinetic sculptures, etc.
# Hobbies & Education: As part of personal robots, CAD designs, engineering experiments, science fair projects, etc.
# Professional Automation Systems: Industrial processes involving repetitive linear or circular actions, such as pick-and-place machinery, packaging lines, medical equipment, security gates, etc.
#
# Technical Specificaitons:
# Type: Continuous Rotary Servomechanism
# Angle Range: Approximately ±90° (+100° max if overdriven without damaging the unit irreversibly).
# Torque Capacity: ~1 kg cm / 1 N m at stall condition
# Power Consumption: Around ⅔ Watt when operating continuously near maximum speed
# Speed: Up to several hundred rpm depending upon applied power level and attached load conditions
# Size: Typically around 60x30 mm² (height × width); weight ranges between ≈20–30 grams
# Interface Connector(s): Generally comes equipped with either JR Micro-Receiver plug connectors or 3-pin header pads suitable for direct connection using appropriate cables or adapters.
# Communication Protocol: Standard pulse width modulation (PWM) signals; typically operates within frequencies between 50 Hz and 50 ms pulses per second. However, some high-end controllers may support faster update rates for improved response times and finer resolution.</s>

# %%
text_24 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_24, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries</s>
#
# Stepper Motor Application using Elegoo UNO R3 & ULN2003 driver:
# To combine these two components - the Elegoo UNO R3 and ULN2003 Stepper Motor Driver Module – you could build a simple CNC machine that moves along X and Y axis controlled via code written within the Arduino environment. The project would involve connecting four wires from each stepper motor's coils to corresponding channels on the ULN2003 driver while also providing power supply connections accordingly. Once this setup has been established, write appropriate software utilizing the Accelstepper library available through GitHub to manage movement instructions sent over serial communication between your computer running GRBL firmware and the Arduino board. By doing so, you will successfully implement basic stepping actions such as moving forward, backward, left, right, and diagonal directions. From there, expand upon this foundation to add additional features like homing sequences, coordinate system implementation, and even Gcode interpretation if desired.</s>

# %%
text_25 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries</s>

"""

device = 'cuda'
model_inputs = tokenizer(text_25, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries</s>
#
# Now let's move onto our third example - The Water Level Detection Sensor Module:
#
# Description:
# The Water Level Detection Sensor Module uses ultrasonic technology to measure water levels accurately within tanks, containers, or other liquid environments. By emitting sound waves that reflect off surfaces underwater and measuring the time taken for those echoes to return, this device calculates distances between itself and the surface of the fluid being measured. As such, it offers valuable insights regarding changes in tank capacity, ensuring efficient usage and preventing potential overflows.
#
# Applications:
# Water level detection plays essential roles in diverse industries and everyday situations where monitoring liquids at varying heights is crucial. Some common application areas include:
# Irrigation Systems: Enabling automatic irrigation management through real-time data about soil moisture levels and reservoir capacities.
# Hydroponics & Aquaculture: Monitoring nutrient solution depths and fish pond conditions respectively.
# Industrial Process Control: Keep track of inventory levels in storage vessels during manufacturing processes.
# Home Automation Projects: Implement smart solutions for managing pool cleaning schedules, toilet fill volumes, etc., while conserving energy consumption.
# Environmental Monitoring: Track groundwater table fluctuations and monitor rainfall patterns effectively.
# Flood Warning Systems: Detect rising floodwaters early enough to issue timely alerts and prevent damage caused due to flooding.
#
# Technical Specificatons:
# Sensing Technology: Ultrasound / Sonar
# Measuring Principle: Time Of Flight Measurement
# Resolution: Typically ranges from 0.1 inches (~2.5 cm) to several feet depending upon model selection
# Accuracy: +/- 1% full scale reading
# Communication Protocol: Supported protocols may vary; commonly includes serial communication via TTL or USB connection
# Power Requirements: Generally operates using standard voltages ranging from 9 VDC – 24 VDC but check manufacturer’s datasheet for exact requirements
# Size: Depends on selected product type; typically small form factor allowing simple mounting configurations
# Calibration Methodology: Calibratable either manually or automatically utilizing built-in calibration functions available in software packages provided by manufacturers.</s>

# %% [markdown]
# # FOUR SHOT PROMPTING

# %%
text_41 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

Here are a few examples for reference,

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries

3. 830 Tie-Points Breadboard:
Description:
A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
Applications:
830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
Technical Specification:
Number of Tie-Points: 830
Construction: Plastic housing with a grid of interconnected metal clips
Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
Color: Typically white or translucent, allowing for clear visibility of component placements and connections.

4. ESP Wroom 32:
Description:
The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
Applications:
The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
Technical Specifications:
Microcontroller: ESP32-D0WDQ6
CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
Bluetooth: Bluetooth v4.2 BR/EDR and BLE
GPIO: 36 general-purpose input/output pins
Memory: 520 KB SRAM, 448 KB ROM
Interfaces: UART, SPI, I2C, I2S, ADC, DAC
Operating Voltage: 3.3 V
Dimensions: 18 mm x 25.5 mm
Operating Temperature: -40°C to 125°C</s>
[INST]Do not print the prompt again[/INST]
"""

device = 'cuda'
model_inputs = tokenizer(text_41, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: hiletgo gy-521 module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# Here are a few examples for reference,
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries
#
# 3. 830 Tie-Points Breadboard:
# Description:
# A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
# Applications:
# 830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
# Technical Specification:
# Number of Tie-Points: 830
# Construction: Plastic housing with a grid of interconnected metal clips
# Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
# Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
# Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
# Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
# Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
# Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
# Color: Typically white or translucent, allowing for clear visibility of component placements and connections.
#
# 4. ESP Wroom 32:
# Description:
# The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
# Applications:
# The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
# Technical Specifications:
# Microcontroller: ESP32-D0WDQ6
# CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
# Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
# Bluetooth: Bluetooth v4.2 BR/EDR and BLE
# GPIO: 36 general-purpose input/output pins
# Memory: 520 KB SRAM, 448 KB ROM
# Interfaces: UART, SPI, I2C, I2S, ADC, DAC
# Operating Voltage: 3.3 V
# Dimensions: 18 mm x 25.5 mm
# Operating Temperature: -40°C to 125°C</s>
# [INST]Do not print the prompt again[/INST]
# Section 1: Description
# -------------------
#
# The HILTECH GO Gy-521 is a wireless temperature & humidity sensing node featuring built-in environmental sensors along with support for LoRa communication technology. This makes it perfect for remote monitoring and logging weather conditions, indoor climate analysis, and even tracking inventory temperatures within warehouses or cold chain logistics operations.
#
# Key aspects include:
# * Integrates two essential sensors – DS18B20 digital thermometer and SHT3x series humidity and temperature sensor
# * Supports LoRa long-range radio frequency transmission protocol
# * Operational autonomy through rechargeable LiPo battery pack (not included)
# * Micro USB port available for charging and PC connection via FTDI programmer
# * Easy setup using popular software platforms like MySensor, Arduino IDE, and others
#
# Section 2: Applications
# ----------------------
#
# Some common uses cases for this versatile IoT solution encompass but aren't limited to:
# * Weather stations: Monitor local atmospheric conditions remotely while maintaining minimal infrastructure costs compared to traditional meteorological equipment.
# * Indoor farming: Keep track of optimal growing environments for plants, ensuring consistent moisture levels and appropriate temperatures throughout greenhouse facilities.
# * Smart homes: Automatically adjust heating, cooling, ventilation settings according to real-time room environment readings.
# * Industrial processes: Ensure stable production line conditions during manufacturing procedures involving sensitive materials requiring controlled climatic parameters.
# * Healthcare: Continuous patient care solutions where accurate temperature and hydration level information must be monitored regularly.
#
# Section 3: Technical Specificatons
# -------------------------------
#
# Specific technical details about the HILTECH GO Gy-521 module follow below:
#
# | Parameter                 | Value               | Unit          |
# |---                       | ---                   |--------------|
# | Dimension             	    | Approximately      | 9 cm × 5.5 cm     |
# | Weight            	        | ~            | 50 grams         |
# | Communication Protocol |LoRa           | N/A            |
# | Power Supply         	    | External          | 5V DC           |
# | Working Range        	    | Up to several km  | Line Of Sight   |
# | Environmental Conditions| Operating Temp.: -10 °C to +50 °C<br>Storage Temp.: -20 °C to +70 °C <br>Relative Humidity: 0% to 100%, non condensing | N/A            |
# | Wireless Transmission | Frequency Band: EU(ISM)/US(FCC)| 868.3–870 MHz / 902–928 MHz |
# | Onboard Storage        | EEPROM memory space | Limited        |
# | Connectivity Options   | Analogue Outputs: 1×I²C bus; Digital IO: 1×UART TX, 1×UART RX; JST XH connector for power supply and expansion options | Various          |
# | Additional Hardware    | Real Time Clock (RTC); SD card slot; Mini OLED display; User buttons and switches | Dependent upon Expansion Board Selection |
# | Software Supported     | Multiple Platforms: Arduino IDE, Contiki OS, Micropython, etc. | Numerous Programming languages supported depending on chosen development framework |
# | Certified Standards    | CE, RoHS compliant | Regulatory compliance varies between regions and configurations |</s>

# %%
text_42 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries

3. 830 Tie-Points Breadboard:
Description:
A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
Applications:
830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
Technical Specification:
Number of Tie-Points: 830
Construction: Plastic housing with a grid of interconnected metal clips
Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
Color: Typically white or translucent, allowing for clear visibility of component placements and connections.

4. ESP Wroom 32:
Description:
The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
Applications:
The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
Technical Specifications:
Microcontroller: ESP32-D0WDQ6
CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
Bluetooth: Bluetooth v4.2 BR/EDR and BLE
GPIO: 36 general-purpose input/output pins
Memory: 520 KB SRAM, 448 KB ROM
Interfaces: UART, SPI, I2C, I2S, ADC, DAC
Operating Voltage: 3.3 V
Dimensions: 18 mm x 25.5 mm
Operating Temperature: -40°C to 125°C</s>
[INST]Do not print the prompt again[/INST]

"""

device = 'cuda'
model_inputs = tokenizer(text_42, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: RC522 RFID Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries
#
# 3. 830 Tie-Points Breadboard:
# Description:
# A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
# Applications:
# 830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
# Technical Specification:
# Number of Tie-Points: 830
# Construction: Plastic housing with a grid of interconnected metal clips
# Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
# Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
# Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
# Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
# Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
# Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
# Color: Typically white or translucent, allowing for clear visibility of component placements and connections.
#
# 4. ESP Wroom 32:
# Description:
# The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
# Applications:
# The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
# Technical Specifications:
# Microcontroller: ESP32-D0WDQ6
# CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
# Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
# Bluetooth: Bluetooth v4.2 BR/EDR and BLE
# GPIO: 36 general-purpose input/output pins
# Memory: 520 KB SRAM, 448 KB ROM
# Interfaces: UART, SPI, I2C, I2S, ADC, DAC
# Operating Voltage: 3.3 V
# Dimensions: 18 mm x 25.5 mm
# Operating Temperature: -40°C to 125°C</s>
# [INST]Do not print the prompt again[/INST]
#
# Section 1: Description
# RC522 RFID Module:
# The RC522 RFID reader module is a popular contactless identification system using radio frequency identification technology. It supports reading MIFARE Classic cards and NFC tags compliant with ISO 14443 type A standard. Featuring simple serial communication protocol, this module makes integrating RFID functionality into your project straightforward.
#
# Application Scenarios:
# Access Control System: Implement secure access control solutions for restricted areas requiring authentication through proximity cards or key fobs.
# Smart Home Automation: Create customized home appliance controls triggered when an authorized tag enters a designated area within the house.
# Retail Industry: Develop inventory management systems where items' information gets updated automatically upon scanning them during checkout processes.
# Healthcare Sector: Design patient monitoring systems enabling quick retrieval of essential medical records while maintaining privacy concerns.
# Public Transportation: Build ticket validation systems ensuring passengers pay only once even if they enter multiple times via different entry points.
# Educational Institutions: Set up library card issuing and tracking systems facilitating seamless borrower registration and resource allocation.
# Gaming & Entertainment Industries: Integrate these readers into games or puzzles adding another layer of excitement and challenge.
#
# Key Technologies:
# * Operates under HF (High Frequency) band, specifically between 13.56 MHz – 14.02 MHz.
# * Uses magnetic field induction coupling method for energy transfer between the antenna coil inside the reader unit and the tag.
# * Supports read ranges varying from just centimeters to several decimetres depending on environmental conditions.
#
# Specifications:
# Communication Protocol: Serial Communication (UART).
# Power Supply Requirements: +5V DC power supply; consumption ~90 mAh @ 12 kbps bit rate.
# Size: Approximately 3 cm × 2.1 cm × 0.8 cm.
# Interface Connections: Four main header pins include MOSI, MISO, SCK, and RESET along with additional ground pin and optional IRQ pin connection.
# Antennas: Two external dipole patch antennas facilitate efficient transmission and reception of signals.
# Security Level: Offers basic security level protection but may require further encryption methods for sensitive applications.
# Programming Language Supported: C++, Python, etc.; compatible with most common development platforms like Arduino.</s>

# %%
text_43 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries

3. 830 Tie-Points Breadboard:
Description:
A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
Applications:
830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
Technical Specification:
Number of Tie-Points: 830
Construction: Plastic housing with a grid of interconnected metal clips
Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
Color: Typically white or translucent, allowing for clear visibility of component placements and connections.

4. ESP Wroom 32:
Description:
The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
Applications:
The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
Technical Specifications:
Microcontroller: ESP32-D0WDQ6
CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
Bluetooth: Bluetooth v4.2 BR/EDR and BLE
GPIO: 36 general-purpose input/output pins
Memory: 520 KB SRAM, 448 KB ROM
Interfaces: UART, SPI, I2C, I2S, ADC, DAC
Operating Voltage: 3.3 V
Dimensions: 18 mm x 25.5 mm
Operating Temperature: -40°C to 125°C</s>
[INST]Do not print the prompt again[/INST]

"""

device = 'cuda'
model_inputs = tokenizer(text_43, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Servo Motor SG90. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries
#
# 3. 830 Tie-Points Breadboard:
# Description:
# A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
# Applications:
# 830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
# Technical Specification:
# Number of Tie-Points: 830
# Construction: Plastic housing with a grid of interconnected metal clips
# Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
# Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
# Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
# Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
# Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
# Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
# Color: Typically white or translucent, allowing for clear visibility of component placements and connections.
#
# 4. ESP Wroom 32:
# Description:
# The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
# Applications:
# The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
# Technical Specifications:
# Microcontroller: ESP32-D0WDQ6
# CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
# Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
# Bluetooth: Bluetooth v4.2 BR/EDR and BLE
# GPIO: 36 general-purpose input/output pins
# Memory: 520 KB SRAM, 448 KB ROM
# Interfaces: UART, SPI, I2C, I2S, ADC, DAC
# Operating Voltage: 3.3 V
# Dimensions: 18 mm x 25.5 mm
# Operating Temperature: -40°C to 125°C</s>
# [INST]Do not print the prompt again[/INST]
#
# Section 1: Description
# ---------------------
#
# Servo Motor SG90 is a popular mini servomotor widely utilized in model aircraft building, robotic arms, CNC machining tools, and similar precision movement applications due to its small form factor and cost effectiveness. These types of servos offer continuous rotation but usually come with limited torque compared to larger models. However, they still deliver sufficient power for most smaller scale projects requiring accurate angular adjustments.
#
# Key Characteristics:
# * Size: Approximately 6 cm long and weighing about 30 grams each
# * Control Signal: Generally operated using pulse width modulation signals between approximately 5ms and 2.5 ms duration
# * Operational Angle Range: Commonly covers ±90 degrees although some variants may reach beyond this limit
# * Power Consumption: Low – under 1 ampere during operation; minimal when idle
#
# Application Scenarios:
# ---------------
# Model Aircraft Building: Incorporates these lightweight yet strong servos within radio controlled airplanes, helicopters, multirotor drones, etc., enabling fine tuned maneuverability through pitch, roll, yaw axis controls.
#
# Robots & Automatons: Utilized extensively in constructing mechanical limbs, grippers, turret heads, and joints where smooth angle changes are essential for efficient performance.
#
# Engraving Machines: Used primarily in desktop engraving equipment, laser cutter setups, and even handheld engravers to ensure consistent cutting depth along curves while producing intricate patterns onto materials ranging from wood to metals.
#
# Art Projects: Artistic endeavours often employ servos to manipulate sculptures, kinetic art pieces, animatronics, and large-scale installations involving complex geometric shapes or moving parts.
#
# Section 2: Applications
# --------------
#
# In addition to those mentioned above, there exist several unique application areas for servo motors SG90:
#
# Medical Devices: Assisting medical procedures via remote patient monitoring systems, rehabilitation exoskeletons, surgical instruments, prosthetic hands, and orthoses.
#
# Security Surveillance Cameras: Enabling pan tilt functionality for security cameras installed indoors or outdoors, ensuring comprehensive coverage area surveillance.
#
# Telepresence Robots: Integrating multiple servos allows creating telepresent avatar bodies capable of mimicking human gestures and expressions remotely.
#
# Educational Tools: Teaching engineering principles related to mechanics, electromechanics, mechatronic concepts, and robotics technology.
#
# Home Entertainment Equipment: Controlling elements inside entertainment centers, such as projector screens, curtains, blinds, lighting fixtures, fans, speakers, and aquarium filters.
#
# Military Technology: Implemented in unmanned ground vehicles, autonomous weapons platforms, reconnaissance units, target tracking systems, bomb disposal robots, and demining machinery.
#
# Space Exploration Probes: Equipping space probes and roving Mars exploration vehicles with high accuracy steerable antennas, solar panel orientation management, landing gear deployment, and sample collection mechanism operations.
#
# Section 3: Technical Specificaitions
# -------------
#
# Here's a summary table containing key technical details regarding the SG90 Mini Servo Motor:
#
# | Parameter          | Value                   | Unit           |
# |---               ---|------------------------|------------------|
# | Length             | ~6cm                    | centimeters     |
# | Weight            | About 30 g              | Grams         |
# | Max Torque        | Up To 1 kg-cm / Nm      | Newton meter       |
# | Stall Torque      | Around 1.5kgf-cm / Nsm  | Newton second metersquare |
# | Rotary Position   | +−90 Degrees            | Degree          |
# | Supply Voltage    | 4.8~6 volts             | voltages         |
# | Efficiency        | >70%                    | Percentage      |
# | Resolution        | <1 degree               | Degree          |
# | Response Time     | Less than 20ms          | Milliseconds    |
# | Noise Level       | Minimal                | Decibels        |
# | Mounting Hole Diameter | M3, M4, M5 | Millimeter |
# | Wire Connections   | Three wired terminals   | Terminals       |
# | Material          | Glass Filled Polyamide | Synthetic material |
# | Shaft End Options  | Ball bearing, plain shaft | Bearings        |
# | Environmental Conditions | Indoor Use Only | Environment conditions |
# | RoHS Certified?   | Yes                     | --              |
# | CE Marked?         | Depends upon manufacturer compliance | --              |
# | Availability      | Worldwide distribution    | Global availability |
# | Price Point       | Affordably priced       | US dollars      |</s>

# %%
text_44 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries

3. 830 Tie-Points Breadboard:
Description:
A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
Applications:
830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
Technical Specification:
Number of Tie-Points: 830
Construction: Plastic housing with a grid of interconnected metal clips
Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
Color: Typically white or translucent, allowing for clear visibility of component placements and connections.

4. ESP Wroom 32:
Description:
The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
Applications:
The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
Technical Specifications:
Microcontroller: ESP32-D0WDQ6
CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
Bluetooth: Bluetooth v4.2 BR/EDR and BLE
GPIO: 36 general-purpose input/output pins
Memory: 520 KB SRAM, 448 KB ROM
Interfaces: UART, SPI, I2C, I2S, ADC, DAC
Operating Voltage: 3.3 V
Dimensions: 18 mm x 25.5 mm
Operating Temperature: -40°C to 125°C</s>
[INST]Do not print the prompt again[/INST]

"""

device = 'cuda'
model_inputs = tokenizer(text_44, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Stepper Motor. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries
#
# 3. 830 Tie-Points Breadboard:
# Description:
# A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
# Applications:
# 830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
# Technical Specification:
# Number of Tie-Points: 830
# Construction: Plastic housing with a grid of interconnected metal clips
# Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
# Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
# Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
# Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
# Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
# Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
# Color: Typically white or translucent, allowing for clear visibility of component placements and connections.
#
# 4. ESP Wroom 32:
# Description:
# The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
# Applications:
# The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
# Technical Specifications:
# Microcontroller: ESP32-D0WDQ6
# CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
# Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
# Bluetooth: Bluetooth v4.2 BR/EDR and BLE
# GPIO: 36 general-purpose input/output pins
# Memory: 520 KB SRAM, 448 KB ROM
# Interfaces: UART, SPI, I2C, I2S, ADC, DAC
# Operating Voltage: 3.3 V
# Dimensions: 18 mm x 25.5 mm
# Operating Temperature: -40°C to 125°C</s>
# [INST]Do not print the prompt again[/INST]
#
# Understood! Here's some additional information about each section you requested regarding the provided IoT Kit Component – a Stepper Motor system consisting of a ULN2003 driver module, an Elegoo UNO R3 controller board, an 830 tie-points breadboard, and an ESP32 WROOM 32 development board.
#
# Section 1: Description
# -------------------
#
# **ULN2003 Stepper Motor Driver:**
# This small yet efficient chipset allows for accurate stepping movement through four phases using six leads. By connecting your chosen stepper motor to this module along with power sources (+5V & Ground), you will effectively convert digital signals generated via the microcontroller into mechanical rotational steps.
#
# **Elegoo UNO R3 Controller Board**:
# As mentioned earlier, the Elegoo UNO R3 is a popular open-source microcontroller board derived from the original Arduino Uno. Featuring the Atmel AVR microchip, it offers ample functionality while being compatible with most shields created for the classic Arduino boards. Additionally, it includes USB connection capability, enabling simple uploading of code directly onto the board.
#
# **Stepper Motor System Setup Diagram:**
# To set up our project utilizing these components, we would first wire the ULN2003 driver module to the Elegoo UNO R3 controller board following the diagram below:
# ```markdown
# +IN1 -> Digital Pin #2
#    |
#    +--|--> IN2 -> Digital Pin #3
#        |
#        +----> IN3 -> Digital Pin #4
#               |
#               +-----|-> IN4 -> Digital Pin #5
#                     |
#                ______|__________
#              |            |
#      STEPPER MOTOR --|------|-------
#                  \      /         \
#                   \    /           \
#                    \/\/             \
#                         GND          ground
# ```
# Next, attach the stepper motor itself to the ULN2003 driver module according to its datasheet recommendations. Last but not least, secure all necessary cables between the Elegoo UNO R3 and the ULN2003 driver module, ensuring they reach the appropriate headers on the former. Once everything has been properly assembled, double check all electrical connections prior to proceeding further.
#
# Now let us move forward towards understanding how exactly these parts function together within different application scenarios.
#
# Section 2: Applications
# ------------------------
#
# Incorporating the described elements—the ULN2003 driver module, Elegoo UNO R3 controller board, 830 tie-point breadboard, and ESP32 Wrover 32 development board—into one coherent setup opens up possibilities ranging from basic robotic arm controllership to intricate CNC machining processes. Below, we outline several common usage cases where combining multiple technologies results in innovative solutions tailored specifically to individual needs.
#
# ### Robot Arm Control
# By integrating servos alongside steppers, complex multi-axis manipulation becomes possible when designing custom robots. For instance, consider creating a three-dimensional printer capable of producing objects layer by layer; here, precision is crucial during every stage of fabrication process. In order to achieve fine adjustments required throughout building structures, employ servomotors for guiding X, Y, Z axis movements whereas utilize stepper motors for managing feedstock extrusion mechanism(s).
#
# ### Automatic Door Opener Project
# An automatic door opener could benefit significantly from implementing a combination of stepper motors and microcontrollers. To build such a solution, configure two unidirectional stepper motors attached back-to-back forming a bi-directional configuration. One motor controls opening actions while another manages closing procedures. Utilize limit switches placed near end positions to ensure safe operation boundaries.
#
# ### Line Follower Bot
# Designing line following robots involves incorporating encoders coupled with either quadrature decoder ICs or dedicated ASICs responsible for counting rotation angles accurately. These readings enable calculating distances traveled by wheels relative to lines drawn on surfaces. Combine this knowledge with stepper motor controlled wheel drive units resulting in autonomous navigation along predefined paths.
#
# With these examples illustrating practical uses of merging technology stacks involving stepper motors, servos, microcontrollers, and wireless communication protocols, there exists endless opportunities waiting to be explored depending upon personal interests and goals.
#
# Section 3: Technical Specificatiions
# ---------------
# Here, we present technical details related to key aspects concerning our selected components:
#
# Component Name | Parameter Value
# --------------|-------------
# ULN2003 Stepper Motor Driver | Operates voltages: 9–36 volts, Maximum current capacity: ~3 Amps, Number of channels: Seven independent full H-bridges
# ESP32 WROVER 32 Development Boa | CPU Clock speed: Up to 240 MHz, Flash memory: 520 kBytes, RAM: 512kBytes, Connectivity options: Wi-Fi, Bluetooth Classic, Bluetooth LE, Ethernet, Serial Port, SDK Supported OS: FreeRTOS, Linux, Windows, MacOS, ChromeOS, Android Studio, Visual Code
# Arduino UNO R3 Microcontroller | Processor type: Atmel SAMAVR Cortex-M4F @ 16 MHz clock rate, Analog inputs: Sixteen 10 bit resolution analog inputs, Communication ports: Two USArt serial ports, Four i²c bus expanders, Eight pulse width modulator outputs, Power requirements: Minimal operating voltage: 7V, Recommended operating voltage: 9V-12V, Dimension: Approximately 69.5x53.4mm
# 830 Point Prototype PCB Test Platform | Size: 22cm × 10 cm, Material: FR4 Epoxy Glass substrate, Thickness: 1.6mm, Drill hole diameter: Ø0.1 inch (2.54mm), Total number of points: 830, Isolation resistance: >1GΩ, Insulating material thickness: ≥1.5mm, Working temperature: −40 °C~+125 °C, Weight: approximately 150 grams.</s>

# %%
text_45 = """<s>[INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
1) Description
2) Applications
3) Technical specifications[/INST]

1. ULN 2003 Stepper Motor Driver Module:
Description:
The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
Applications:
The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
Robotics: for precise control of robot movements.
CNC machines: for controlling the motion of axes.
3D printers: for controlling the position of the printing head.
Automated systems: for controlling mechanisms like conveyor belts and automated doors.
DIY projects: for hobbyists and enthusiasts working on motion control projects.
Technical Specifications:
Operating Voltage: 5V DC
Output Current: up to 500mA per channel (with proper heat sinking)
Driver IC: ULN2003A Darlington Array
Number of Channels: 7 (suitable for driving bipolar stepper motors)
Compatible Motors: Bipolar stepper motors with 4 or 6 wires
Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
Dimensions: Compact module size for easy integration into projects
Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
Mounting Holes: Provided for easy installation and integration into projects

2. Elegoo UNO R3 controller board:

Description:
The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.

Applications:
The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
Technical Specifications:
Microcontroller: ATmega328P
Operating Voltage: 5V
Input Voltage (recommended): 7-12V
Digital I/O Pins: 14 (of which 6 provide PWM output)
Analog Input Pins: 6
Flash Memory: 32 KB (0.5 KB used by bootloader)
SRAM: 2 KB
EEPROM: 1 KB
Clock Speed: 16 MHz
USB Interface: Type-B
Dimensions: 68.6mm x 53.4mm
Weight: 25g
Compatible with Arduino IDE
Supported by a vast community with extensive resources, tutorials, and libraries

3. 830 Tie-Points Breadboard:
Description:
A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
Applications:
830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
Technical Specification:
Number of Tie-Points: 830
Construction: Plastic housing with a grid of interconnected metal clips
Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
Color: Typically white or translucent, allowing for clear visibility of component placements and connections.

4. ESP Wroom 32:
Description:
The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
Applications:
The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
Technical Specifications:
Microcontroller: ESP32-D0WDQ6
CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
Bluetooth: Bluetooth v4.2 BR/EDR and BLE
GPIO: 36 general-purpose input/output pins
Memory: 520 KB SRAM, 448 KB ROM
Interfaces: UART, SPI, I2C, I2S, ADC, DAC
Operating Voltage: 3.3 V
Dimensions: 18 mm x 25.5 mm
Operating Temperature: -40°C to 125°C</s>
[INST]Do not print the prompt again[/INST]

"""

device = 'cuda'
model_inputs = tokenizer(text_45, return_tensors="pt").to(model_4bit.device)

generated_ids = model_4bit.generate(**model_inputs, temperature=0.1, top_k=1, top_p=1.0, repetition_penalty=1.4, min_new_tokens=16, max_new_tokens=2000, do_sample=True)
decoded = tokenizer.decode(generated_ids[0])
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s><s> [INST]You are an expert in IoT and hardware with extensive experience. You have been given an IoT kit component: Water Level Detection Sensor Module. Give a description of the component having 3 sections as follows:
# 1) Description
# 2) Applications
# 3) Technical specifications[/INST]
#
# 1. ULN 2003 Stepper Motor Driver Module:
# Description:
# The ULN2003 Stepper Motor Driver Module is an integrated circuit module designed to control bipolar stepper motors conveniently. It utilizes the ULN2003A Darlington array as its core component. This module provides an easy interface for controlling stepper motors, offering both simplicity and efficiency in motor control applications.
# Applications:
# The ULN2003 Stepper Motor Driver Module finds widespread use in various projects and applications, including:
# Robotics: for precise control of robot movements.
# CNC machines: for controlling the motion of axes.
# 3D printers: for controlling the position of the printing head.
# Automated systems: for controlling mechanisms like conveyor belts and automated doors.
# DIY projects: for hobbyists and enthusiasts working on motion control projects.
# Technical Specifications:
# Operating Voltage: 5V DC
# Output Current: up to 500mA per channel (with proper heat sinking)
# Driver IC: ULN2003A Darlington Array
# Number of Channels: 7 (suitable for driving bipolar stepper motors)
# Compatible Motors: Bipolar stepper motors with 4 or 6 wires
# Control Interface: 4-phase, 5-wire interface (can be easily interfaced with microcontrollers like Arduino)
# Dimensions: Compact module size for easy integration into projects
# Protection Features: Built-in transient suppression diodes for protecting the module and connected components against voltage spikes
# Mounting Holes: Provided for easy installation and integration into projects
#
# 2. Elegoo UNO R3 controller board:
#
# Description:
# The Elegoo UNO R3 controller board is a versatile microcontroller board based on the Arduino UNO R3 design. It serves as the brain of numerous DIY electronics projects, offering a compact and user-friendly platform for both beginners and advanced users alike. With its robust construction and compatibility with a wide range of sensors, actuators, and modules, it empowers enthusiasts to bring their ideas to life.
#
# Applications:
# The Elegoo UNO R3 finds applications across various fields including robotics, home automation, IoT (Internet of Things), educational projects, and prototyping. It can be used to create interactive installations, automate tasks, develop sensor-based systems, and much more. Its flexibility and ease of programming make it an ideal choice for hobbyists, students, educators, and professionals seeking to innovate in the realm of electronics and embedded systems.
# Technical Specifications:
# Microcontroller: ATmega328P
# Operating Voltage: 5V
# Input Voltage (recommended): 7-12V
# Digital I/O Pins: 14 (of which 6 provide PWM output)
# Analog Input Pins: 6
# Flash Memory: 32 KB (0.5 KB used by bootloader)
# SRAM: 2 KB
# EEPROM: 1 KB
# Clock Speed: 16 MHz
# USB Interface: Type-B
# Dimensions: 68.6mm x 53.4mm
# Weight: 25g
# Compatible with Arduino IDE
# Supported by a vast community with extensive resources, tutorials, and libraries
#
# 3. 830 Tie-Points Breadboard:
# Description:
# A 830 Tie-Points Breadboard is a solderless electronic testing device used for prototyping and experimenting with electronic circuits. It typically consists of a grid of interconnected holes or slots, allowing users to easily insert and connect electronic components without the need for soldering. The holes or slots are typically organized in rows and columns, providing a convenient layout for circuit design and assembly.
# Applications:
# 830 Tie-Points Breadboards find extensive use in electronics labs, classrooms, and hobbyist projects. They are ideal for rapid prototyping of circuits, allowing engineers and hobbyists to quickly test circuit designs and troubleshoot potential issues before committing to a permanent soldered prototype. They are commonly used for experimenting with microcontrollers, sensors, LEDs, resistors, capacitors, and other electronic components.
# Technical Specification:
# Number of Tie-Points: 830
# Construction: Plastic housing with a grid of interconnected metal clips
# Dimensions: Typically around 6.5 inches x 2.2 inches (165mm x 55mm)
# Hole/Slot Pitch: Standard 0.1-inch (2.54mm) spacing
# Voltage/Current Rating: Typically suitable for low-voltage and low-current applications (e.g., up to 30V and a few hundred milliamps)
# Compatibility: Compatible with a wide range of electronic components including resistors, capacitors, integrated circuits, and jumper wires.
# Durability: Designed for repeated use with components easily inserted and removed without damaging the breadboard.
# Mounting: Often equipped with adhesive backing for easy mounting on a flat surface.
# Color: Typically white or translucent, allowing for clear visibility of component placements and connections.
#
# 4. ESP Wroom 32:
# Description:
# The ESP Wroom 32 is a powerful and versatile microcontroller module developed by Espressif Systems. It is based on the ESP32 series of chips, which integrate Wi-Fi and Bluetooth capabilities, making it ideal for Internet of Things (IoT) applications. The module features a compact design and comes with various GPIO pins, allowing for easy integration into a wide range of projects.
# Applications:
# The ESP Wroom 32 finds applications in diverse fields such as home automation, industrial automation, smart agriculture, wearable devices, and IoT sensor networks. It can be used to create connected devices that gather data from sensors, communicate with other devices over Wi-Fi or Bluetooth, and interact with cloud services for data processing and storage.
# Technical Specifications:
# Microcontroller: ESP32-D0WDQ6
# CPU: Dual-core 32-bit LX6 microprocessor, running at up to 240 MHz
# Wi-Fi: 802.11 b/g/n (2.4 GHz) and 802.11 a/n/ac (5 GHz)
# Bluetooth: Bluetooth v4.2 BR/EDR and BLE
# GPIO: 36 general-purpose input/output pins
# Memory: 520 KB SRAM, 448 KB ROM
# Interfaces: UART, SPI, I2C, I2S, ADC, DAC
# Operating Voltage: 3.3 V
# Dimensions: 18 mm x 25.5 mm
# Operating Temperature: -40°C to 125°C</s>
# [INST]Do not print the prompt again[/INST]
#
# Section 1: Description
# ---------------------
#
# Water Level Detection Sensor Module is an essential IoT component specifically engineered for monitoring water levels in tanks, reservoirs, pools, aquariums, and similar environments. By continuously measuring changes in conductivity caused by varying liquid heights, this non-contact level sensing technology offers accurate readings while minimizing interference from external factors.
#
# Key advantages include high precision, long service life due to solid state design, immunity to electromagnetic noise, and resistance to harsh conditions common in wet environments. These characteristics enable reliable operation even under challenging circumstances where traditional float switches may fail.
#
# Application areas span industries ranging from agricultural irrigation management, wastewater treatment plants, HVAC systems, hydroelectric power generation facilities, oil refineries, chemical manufacturing processes, and many others requiring continuous real-time information about fluid inventory levels. Additionally, residential uses include tracking swimming pool chemicals, managing rain barrel collection systems, and ensuring adequate coolant levels within air conditioner units.
#
# Section 2: Applications
# ----------------------
#
# * Agricultural irrigation management: Monitor soil moisture content and optimize crop growth through efficient water usage.
# * Industrial process control: Ensure consistent production rates by maintaining optimal tank fill levels in factories producing food products, pharmaceuticals, petrochemicals, etc.
# * Smart homes & buildings: Automatically manage heating system temperatures using real-time cooling tower water level measurements; monitor pool chemistry levels remotely via mobile apps.
# * Renewable energy sector: Optimally operate hydropower turbines according to available water volume.
# * Aquarium maintenance: Keep track of water quality parameters and ensure appropriate filtration cycles.
# * Flood detection systems: Early warning flood prevention measures utilizing real-time water height measurement data.
#
# Section 3: Technical Specificatons
# -------------------------------
#
# Sensor Principle: Capacitive coupling method detects variations in dielectric constant between two electrodes submerged inside the target medium.
# Communication Protocol: Supported communication protocols include Modbus RTU, NPN-MODBUS TCP/IP, HTTP API, MQTT, OPC UA, among others depending upon application requirements.
# Power Supply Requirements: Operates efficiently within a broad supply voltage range (9~36Vdc).
# Environmental Conditions: Suited for indoor and outdoor deployments (-40°F ~ +140°F / -40°C ~ +60°C temperature ranges); IP67 rated enclosure ensures protection against dust ingress and submersion in shallow waters.
# Accuracy: ±(x% of FS) accuracy depends on selected model type and calibration settings. For instance, models catering to large volumes might offer lower resolution but higher overall coverage area compared to those intended for smaller containers.
# Resolution: Depending on chosen configuration options, resolutions down to 0.1 inch (2.5 cm) can be achieved when employing multiple sensors strategically placed along container walls.
# Response Time: Fast response times allow quick updates of measured values – crucial during critical situations involving overflow warnings or pump activation thresholds.
# Calibration Methodology: Calibrate each unit individually using known reference points or predefined lookup tables provided by manufacturers tailored to different vessel geometries and materials. Regular recalibration helps maintain desired performance consistency throughout extended periods.</s>
